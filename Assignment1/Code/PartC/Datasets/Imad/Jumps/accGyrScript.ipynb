# %%
import pandas as pd
import numpy as np

acc = pd.read_csv("./Accelerometer.csv")
acc.drop(columns='Time (s)')
gyr = pd.read_csv("./Gyroscope.csv")
gyr.drop(columns='Time (s)')

activity = pd.DataFrame(columns= ["X (m/s^2)","Y (m/s^2)","Z (m/s^2)", "X (rad/s)", "Y (rad/s)", "Z (rad/s)"])

# %%
activity['X (m/s^2)'] = acc['X (m/s^2)'].values
activity['Y (m/s^2)'] = acc['Y (m/s^2)'].values
activity['Z (m/s^2)'] = acc['Z (m/s^2)'].values
activity['X (rad/s)'] = gyr['X (rad/s)'].values
activity['Y (rad/s)'] = gyr['Y (rad/s)'].values
activity['Z (rad/s)'] = gyr['Z (rad/s)'].values

activity["Subject"] = 1
activity["Activity"] = "Jumping"

# %%
activity
# Out:
#       X (m/s^2)  Y (m/s^2)  Z (m/s^2)  X (rad/s)  Y (rad/s)  Z (rad/s)  \
# 0     -3.298092  -8.242160  -1.299148  -0.232351  -0.387127  -0.468749
# 1     -3.428620  -8.226742  -1.342558  -0.236278  -0.275373  -0.451109
# 2     -3.196902  -8.143815  -1.588796  -0.193396  -0.289539  -0.444967
# 3     -2.365231  -7.839947  -1.751957  -0.070750  -0.466346  -0.412877
# 4     -1.199456  -7.485334  -2.040257   0.104060  -0.696491  -0.350199
# ...         ...        ...        ...        ...        ...        ...
# 2979  -4.192631 -11.323652 -11.065290   0.168860  -0.489731   0.152948
# 2980  -4.872967 -14.108910 -10.932366   1.319065  -0.038678   0.094217
# 2981  -4.556974 -16.807199  -7.317533   1.726816   0.755395   0.051747
# 2982  -3.534001 -20.048110  -0.960403   1.551048   1.538150  -0.052407
# 2983  -2.602787 -25.331673   3.485801   0.802476   2.018094  -0.276622
#
#       Subject Activity
# 0           1  Jumping
# 1           1  Jumping
# 2           1  Jumping
# 3           1  Jumping
# 4           1  Jumping
# ...       ...      ...
# 2979        1  Jumping
# 2980        1  Jumping
# 2981        1  Jumping
# 2982        1  Jumping
# 2983        1  Jumping
#
# [2984 rows x 8 columns]

# %%
activity.to_csv('imadJumps.csv')
