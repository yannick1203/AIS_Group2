# %%
import pandas as pd
import numpy as np

acc = pd.read_csv("./Accelerometer.csv")
acc.drop(columns='Time (s)')
gyr = pd.read_csv("./Gyroscope.csv")
gyr.drop(columns='Time (s)')

activity = pd.DataFrame(columns= ["X (m/s^2)","Y (m/s^2)","Z (m/s^2)", "X (rad/s)", "Y (rad/s)", "Z (rad/s)"])

# %%
activity['X (m/s^2)'] = acc['X (m/s^2)'].values
activity['Y (m/s^2)'] = acc['Y (m/s^2)'].values
activity['Z (m/s^2)'] = acc['Z (m/s^2)'].values
activity['X (rad/s)'] = gyr['X (rad/s)'].values
activity['Y (rad/s)'] = gyr['Y (rad/s)'].values
activity['Z (rad/s)'] = gyr['Z (rad/s)'].values

activity["Subject"] = 1
activity["Activity"] = "Squads"

# %%
activity
# Out:
#       X (m/s^2)  Y (m/s^2)  Z (m/s^2)  X (rad/s)  Y (rad/s)  Z (rad/s)  \
# 0      2.195634  -9.025032  -1.187032   0.866591  -1.320718   0.138434
# 1      2.361190  -8.079598  -0.718356   0.749830  -1.338568  -0.079125
# 2      2.270029  -7.290589  -0.557890   0.638242  -1.244808  -0.354937
# 3      2.088457  -7.217092  -0.602048   0.583448  -1.117797  -0.588610
# 4      2.233954  -7.755672  -0.686622   0.570193  -1.043774  -0.706738
# ...         ...        ...        ...        ...        ...        ...
# 2979   5.175338  -7.756271  -8.622220  -1.947827   0.169636  -0.154163
# 2980   4.851112  -6.857689  -7.748188  -1.803477  -0.204242   0.114885
# 2981   3.484753  -5.906867  -6.139483  -1.949500  -0.546797   0.232242
# 2982   1.269959  -4.658313  -5.573809  -2.202888  -0.629299   0.276931
# 2983  -0.390238  -2.859953  -6.435417  -2.307373  -0.518168   0.326266
#
#       Subject Activity
# 0           1   Squads
# 1           1   Squads
# 2           1   Squads
# 3           1   Squads
# 4           1   Squads
# ...       ...      ...
# 2979        1   Squads
# 2980        1   Squads
# 2981        1   Squads
# 2982        1   Squads
# 2983        1   Squads
#
# [2984 rows x 8 columns]

# %%
activity.to_csv('imadSquads.csv', index=False)
