# %%
import pandas as pd
import numpy as np

acc = pd.read_csv("./Accelerometer.csv")
acc.drop(columns='Time (s)')
gyr = pd.read_csv("./Gyroscope.csv")
gyr.drop(columns='Time (s)')

activity = pd.DataFrame(columns= ["X (m/s^2)","Y (m/s^2)","Z (m/s^2)", "X (rad/s)", "Y (rad/s)", "Z (rad/s)"])

# %%
activity['X (m/s^2)'] = acc['X (m/s^2)'].values
activity['Y (m/s^2)'] = acc['Y (m/s^2)'].values
activity['Z (m/s^2)'] = acc['Z (m/s^2)'].values
activity['X (rad/s)'] = gyr['X (rad/s)'].values
activity['Y (rad/s)'] = gyr['Y (rad/s)'].values
activity['Z (rad/s)'] = gyr['Z (rad/s)'].values

activity["Subject"] = 1
activity["Activity"] = "Pushups"

# %%
activity
# Out:
#       X (m/s^2)  Y (m/s^2)  Z (m/s^2)  X (rad/s)  Y (rad/s)  Z (rad/s)  \
# 0     -5.115462  -4.136797   4.995113   0.835351   0.305875  -0.972878
# 1     -5.385052  -3.862268   5.147047   0.839788   0.425145  -0.903230
# 2     -6.157296  -3.444637   5.137018   0.781373   0.432300  -0.785790
# 3     -7.370673  -3.050057   5.302873   0.589800   0.137142  -0.653778
# 4     -8.700058  -2.728975   5.603597   0.164209  -1.140218  -0.434777
# ...         ...        ...        ...        ...        ...        ...
# 2976  -5.845345  -0.827330   7.250023  -0.314715   0.114130  -0.182203
# 2977  -5.890551  -1.122815   7.093898  -0.313049   0.103065  -0.196085
# 2978  -5.875881  -1.350342   6.820866  -0.320067   0.130680  -0.222291
# 2979  -5.860014  -1.560056   6.510711  -0.324113   0.179485  -0.248641
# 2980  -5.771548  -1.658102   6.252348  -0.305854   0.244737  -0.254804
#
#       Subject Activity
# 0           1  Pushups
# 1           1  Pushups
# 2           1  Pushups
# 3           1  Pushups
# 4           1  Pushups
# ...       ...      ...
# 2976        1  Pushups
# 2977        1  Pushups
# 2978        1  Pushups
# 2979        1  Pushups
# 2980        1  Pushups
#
# [2981 rows x 8 columns]

# %%
activity.to_csv('imadPushups.csv', index=False)
