# %%
import pandas as pd
import numpy as np

acc = pd.read_csv("./Accelerometer.csv")
acc.drop(columns='Time (s)')
gyr = pd.read_csv("./Gyroscope.csv")
gyr.drop(columns='Time (s)')

activity = pd.DataFrame(columns= ["X (m/s^2)","Y (m/s^2)","Z (m/s^2)", "X (rad/s)", "Y (rad/s)", "Z (rad/s)"])

# %%
activity['X (m/s^2)'] = acc['X (m/s^2)'].values
activity['Y (m/s^2)'] = acc['Y (m/s^2)'].values
activity['Z (m/s^2)'] = acc['Z (m/s^2)'].values
activity['X (rad/s)'] = gyr['X (rad/s)'].values
activity['Y (rad/s)'] = gyr['Y (rad/s)'].values
activity['Z (rad/s)'] = gyr['Z (rad/s)'].values

activity["Subject"] = 2
activity["Activity"] = "Squads"

# %%
activity
# Out:
#       X (m/s^2)  Y (m/s^2)  Z (m/s^2)  X (rad/s)  Y (rad/s)  Z (rad/s)  \
# 0     11.671379  -6.517597 -10.545870  -1.369881  -0.233031  -1.510033
# 1     10.050999  -6.807843 -10.495874  -1.272910  -0.235388  -1.354632
# 2      7.267088  -6.046376 -10.193652  -1.151012  -0.009451  -1.142347
# 3      6.358028  -4.617747  -9.694440  -1.155085  -0.076514  -0.885736
# 4      6.763236  -3.248994 -10.206226  -1.156785   0.116356  -0.793595
# ...         ...        ...        ...        ...        ...        ...
# 3008   1.786834  -8.275541  -2.088756   2.089676  -0.053751   1.720163
# 3009   1.901047  -7.910899  -1.980082   2.062771  -0.038379   1.625532
# 3010   2.002236  -7.140002  -2.041305   1.940600  -0.044498   1.518750
# 3011   2.145339  -6.194119  -2.294429   1.811887  -0.056767   1.386486
# 3012   2.291285  -5.207671  -2.260150   1.660734  -0.012743   1.238227
#
#       Subject Activity
# 0           2   Squads
# 1           2   Squads
# 2           2   Squads
# 3           2   Squads
# 4           2   Squads
# ...       ...      ...
# 3008        2   Squads
# 3009        2   Squads
# 3010        2   Squads
# 3011        2   Squads
# 3012        2   Squads
#
# [3013 rows x 8 columns]

# %%
activity.to_csv('jaylongSquads.csv')
