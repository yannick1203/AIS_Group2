# %%
import pandas as pd
import numpy as np

acc = pd.read_csv("./Accelerometer.csv")
acc.drop(columns='Time (s)')
gyr = pd.read_csv("./Gyroscope.csv")
gyr.drop(columns='Time (s)')

activity = pd.DataFrame(columns= ["X (m/s^2)","Y (m/s^2)","Z (m/s^2)", "X (rad/s)", "Y (rad/s)", "Z (rad/s)"])

# %%
activity['X (m/s^2)'] = acc['X (m/s^2)'].values
activity['Y (m/s^2)'] = acc['Y (m/s^2)'].values
activity['Z (m/s^2)'] = acc['Z (m/s^2)'].values
activity['X (rad/s)'] = gyr['X (rad/s)'].values
activity['Y (rad/s)'] = gyr['Y (rad/s)'].values
activity['Z (rad/s)'] = gyr['Z (rad/s)'].values

activity["Subject"] = 2
activity["Activity"] = "Pushups"

# %%
activity
# Out:
#       X (m/s^2)  Y (m/s^2)  Z (m/s^2)  X (rad/s)  Y (rad/s)  Z (rad/s)  \
# 0     -7.102580   0.034428   7.284452   0.010394   0.048785  -0.127496
# 1     -6.977440   0.258961   6.761739  -0.025250   0.035242  -0.125538
# 2     -6.916367   0.450713   6.268814  -0.068118  -0.014683  -0.103665
# 3     -6.840924   0.533191   5.995033  -0.109232  -0.077111  -0.069404
# 4     -6.833589   0.537682   6.017936  -0.129609  -0.150754  -0.037810
# ...         ...        ...        ...        ...        ...        ...
# 3010  -6.638246   1.016835   9.030721   0.124809   0.289572  -0.151023
# 3011  -7.652986   0.252675   8.392448   0.142889   0.213366  -0.119184
# 3012  -8.620573  -0.338746   7.707622   0.021265   0.012874  -0.044952
# 3013  -9.031619  -0.299976   7.015910  -0.182761  -0.099333   0.016118
# 3014  -8.173154   0.498314   6.793024  -0.288491  -0.092254   0.024211
#
#       Subject Activity
# 0           2  Pushups
# 1           2  Pushups
# 2           2  Pushups
# 3           2  Pushups
# 4           2  Pushups
# ...       ...      ...
# 3010        2  Pushups
# 3011        2  Pushups
# 3012        2  Pushups
# 3013        2  Pushups
# 3014        2  Pushups
#
# [3015 rows x 8 columns]

# %%
activity.to_csv('jaylongPushups.csv')
